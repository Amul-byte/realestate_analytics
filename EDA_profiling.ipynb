# %% [markdown]
# **Profiling**
# - This tool is usefull to do all the data analysis and generate the quick overview and rough idea about it very very helpfull.

# %%
import pandas as pd
from ydata_profiling import ProfileReport

df = pd.read_csv("datasets/gurgaon_properties_v1.csv").drop_duplicates()
profile = ProfileReport(df, title="Pandas Profiling Report", explorative=True)
profile.to_file("output_report.html")
# Out:
# ...
# Export report to file: 100%|██████████| 1/1 [00:00<00:00, 160.96it/s]

# %%
import webbrowser
webbrowser.open("output_report.html")
# Out:
# True
